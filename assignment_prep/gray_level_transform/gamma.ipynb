# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

def convert_image_to_grayscale(image_path):
    img = Image.open(image_path).convert('L')
    gray_matrix = np.array(img)
    return gray_matrix

def display_image(matrix, cmap='gray'):
    plt.imshow(matrix, cmap=cmap)
    plt.show()

def log_transform(matrix):
    c = 0.15
    gamma = 0.1
    transformed = c * (matrix ** gamma)

    transformed = (transformed / np.max(transformed)) * 255
    return transformed

def process_image(image_path):
    gray_matrix = convert_image_to_grayscale(image_path)
    print("Original Grayscale Matrix:")
    print(gray_matrix)
    
    trans = log_transform(gray_matrix)
    print("Log-Transformed Matrix:")
    print(trans)
    
    display_image(gray_matrix)
    display_image(trans)

# %%
process_image('./image.jpeg')
# Out:
# Original Grayscale Matrix:
# [[214 214 214 ... 223 223 244]
#  [146 146 146 ... 171 171 223]
#  [146 146 146 ... 171 171 223]
#  ...
#  [ 42  42  40 ...  43  44 176]
#  [ 42  41  40 ...  44  44 176]
#  [174 174 173 ... 176 176 229]]
# Log-Transformed Matrix:
# [[251.67644752 251.67644752 251.67644752 ... 252.7153862  252.7153862
#   255.        ]
#  [242.2347712  242.2347712  242.2347712  ... 246.09387733 246.09387733
#   252.7153862 ]
#  [242.2347712  242.2347712  242.2347712  ... 246.09387733 246.09387733
#   252.7153862 ]
#  ...
#  [213.85830819 213.85830819 212.81743128 ... 214.36211994 214.85549503
#   246.8041537 ]
#  [213.85830819 213.34358246 212.81743128 ... 214.85549503 214.85549503
#   246.8041537 ]
#  [246.52224986 246.52224986 246.38020266 ... 246.8041537  246.8041537
#   253.38724292]]
