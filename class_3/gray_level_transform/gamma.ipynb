# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

def convert_image_to_grayscale(image_path):
    img = Image.open(image_path).convert('L')
    gray_matrix = np.array(img)
    return gray_matrix

def display_image(matrix, cmap='gray'):
    plt.imshow(matrix, cmap=cmap)
    plt.show()

def log_transform(matrix):
    c = 0.5
    gamma = 0.8
    transformed = c * (matrix ** gamma)

    transformed = (transformed / np.max(transformed)) * 255
    return transformed

def process_image(image_path):
    gray_matrix = convert_image_to_grayscale(image_path)
    print("Original Grayscale Matrix:")
    print(gray_matrix)
    
    trans = log_transform(gray_matrix)
    print("Log-Transformed Matrix:")
    print(trans)
    
    display_image(gray_matrix)
    display_image(trans)

# %%
process_image('./image.jpeg')
# Out:
# Original Grayscale Matrix:
# [[214 214 214 ... 223 223 244]
#  [146 146 146 ... 171 171 223]
#  [146 146 146 ... 171 171 223]
#  ...
#  [ 42  42  40 ...  43  44 176]
#  [ 42  41  40 ...  44  44 176]
#  [174 174 173 ... 176 176 229]]
# Log-Transformed Matrix:
# [[229.59336752 229.59336752 229.59336752 ... 237.2860516  237.2860516
#   255.        ]
#  [169.08714997 169.08714997 169.08714997 ... 191.87801088 191.87801088
#   237.2860516 ]
#  [169.08714997 169.08714997 169.08714997 ... 191.87801088 191.87801088
#   237.2860516 ]
#  ...
#  [ 62.40620188  62.40620188  60.01728045 ...  63.59208783  64.7724703
#   196.35341258]
#  [ 62.40620188  61.21465479  60.01728045 ...  64.7724703   64.7724703
#   196.35341258]
#  [194.56634383 194.56634383 193.67127063 ... 196.35341258 196.35341258
#   242.37995764]]
