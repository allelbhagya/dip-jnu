# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('cat.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img_canny = cv2.Canny(img, 100, 200)

kernelx = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])
kernely = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]])
img_prewittx = cv2.filter2D(gray, -1, kernelx)
img_prewitty = cv2.filter2D(gray, -1, kernely)
img_prewitt = img_prewittx + img_prewitty

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_canny_rgb = cv2.cvtColor(img_canny, cv2.COLOR_GRAY2RGB)
img_prewitt_rgb = cv2.cvtColor(img_prewitt, cv2.COLOR_GRAY2RGB)

fig, axes = plt.subplots(1, 3, figsize=(20, 5))
axes[0].imshow(img_rgb)
axes[0].set_title("Original Image")
axes[1].imshow(img_canny_rgb)
axes[1].set_title("Canny Edge")
axes[2].imshow(img_prewitt_rgb)
axes[2].set_title("Prewitt Edge")

for ax in axes:
    ax.axis('off')

plt.show()
