# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np

# %%
img = mpimg.imread('../image.jpeg')
plt.imshow(img)

# %%
random_img = np.random.random([500,500])
plt.imshow(random_img)
print(random_img)
# Out:
# [[0.73833684 0.75006704 0.79628025 ... 0.25000155 0.99594808 0.23438966]
#  [0.80120588 0.03851868 0.80158427 ... 0.75007647 0.58150901 0.42409846]
#  [0.92336917 0.10718317 0.21727294 ... 0.55975367 0.92460262 0.77283468]
#  ...
#  [0.9178083  0.61763685 0.06926167 ... 0.66625539 0.63539279 0.66689182]
#  [0.14564266 0.30177004 0.10112267 ... 0.6397243  0.09324079 0.8354464 ]
#  [0.95809435 0.20410526 0.7158939  ... 0.47761886 0.70743937 0.86389563]]
