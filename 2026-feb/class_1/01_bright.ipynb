# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('lung.jpg', cv2.IMREAD_GRAYSCALE)


plt.imshow(image, cmap='gray')
plt.title("Original Lung X-ray")
plt.axis('off')
plt.show()

# %%
brightness = 100

bright_image = cv2.add(image, brightness)

plt.imshow(bright_image, cmap='gray')
plt.title("Brightness Adjusted")
plt.axis('off')
plt.show()

cv2.imwrite('lung_xray_bright.jpg', bright_image)
# Out:
# True

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(image, cmap='gray')
plt.title("Original")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(bright_image, cmap='gray')
plt.title("Brightness Adjusted")
plt.axis("off")

plt.tight_layout()
plt.show()
