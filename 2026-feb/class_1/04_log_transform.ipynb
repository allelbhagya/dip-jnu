# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

def convert_image_to_grayscale(image_path):
    img = Image.open(image_path).convert('L')
    gray_matrix = np.array(img)
    return gray_matrix

def display_image(matrix, cmap='gray'):
    plt.imshow(matrix, cmap=cmap)
    plt.show()

def log_transform(matrix):
    c = 0.5
    transformed = c * np.log(1 + matrix)

    transformed = (transformed / np.max(transformed)) * 255
    return transformed

def process_image(image_path):
    gray_matrix = convert_image_to_grayscale(image_path)
    print("Original Grayscale Matrix:")
    print(gray_matrix)
    
    trans = log_transform(gray_matrix)
    print("Log-Transformed Matrix:")
    print(trans)
    
    display_image(gray_matrix)
    display_image(trans)

# %%
process_image('cat2.jpeg')
# Out:
# Original Grayscale Matrix:
# [[214 214 214 ... 223 223 244]
#  [146 146 146 ... 171 171 223]
#  [146 146 146 ... 171 171 223]
#  ...
#  [ 42  42  40 ...  43  44 176]
#  [ 42  41  40 ...  44  44 176]
#  [174 174 173 ... 176 176 229]]
# Log-Transformed Matrix:
# [[249.  249.  249.  ... 250.9 250.9 255. ]
#  [231.5 231.5 231.5 ... 238.8 238.8 250.9]
#  [231.5 231.5 231.5 ... 238.8 238.8 250.9]
#  ...
#  [174.5 174.5 172.2 ... 175.4 176.4 239.9]
#  [174.5 173.4 172.2 ... 176.4 176.4 239.9]
#  [239.4 239.4 239.1 ... 239.9 239.9 252.1]]
