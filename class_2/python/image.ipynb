# %%
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('../image.jpeg')

plt.imshow(img)
plt.show()
img
# Out:
# array([[[201, 217, 230],
#         [201, 217, 230],
#         [201, 217, 230],
#         ...,
#         [212, 226, 237],
#         [212, 226, 237],
#         [241, 244, 249]],
#
#        [[112, 155, 189],
#         [112, 155, 189],
#         [112, 155, 189],
#         ...,
#         [143, 178, 210],
#         [143, 178, 210],
#         [212, 226, 237]],
#
#        [[112, 155, 189],
#         [112, 155, 189],
#         [112, 155, 189],
#         ...,
#         [143, 178, 210],
#         [143, 178, 210],
#         [212, 226, 237]],
#
#        ...,
#
#        [[ 31,  48,  40],
#         [ 31,  48,  40],
#         [ 29,  46,  38],
#         ...,
#         [ 32,  49,  43],
#         [ 33,  50,  44],
#         [172, 178, 176]],
#
#        [[ 31,  48,  40],
#         [ 30,  47,  39],
#         [ 29,  46,  38],
#         ...,
#         [ 33,  50,  44],
#         [ 33,  50,  44],
#         [172, 178, 176]],
#
#        [[170, 176, 174],
#         [170, 176, 174],
#         [169, 175, 173],
#         ...,
#         [172, 178, 176],
#         [172, 178, 176],
#         [228, 230, 229]]], dtype=uint8)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

gray = rgb2gray(img)
plt.imshow(gray, cmap=plt.get_cmap('gray'))
plt.show()

# %%
gray
# Out:
# array([[213.6779, 213.6779, 213.6779, ..., 223.0468, 223.0468, 243.6489],
#        [146.0078, 146.0078, 146.0078, ..., 171.1687, 171.1687, 223.0468],
#        [146.0078, 146.0078, 146.0078, ..., 171.1687, 171.1687, 223.0468],
#        ...,
#        [ 42.0019,  42.0019,  40.0021, ...,  43.2298,  44.2297, 175.9608],
#        [ 42.0019,  41.002 ,  40.0021, ...,  44.2297,  44.2297, 175.9608],
#        [173.961 , 173.961 , 172.9611, ..., 175.9608, 175.9608, 229.2652]])
